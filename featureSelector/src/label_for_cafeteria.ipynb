# %%
import pandas as pd

# %%
df_org = pd.read_csv('../data/c4_general_cafeteria_chuncheon_CC_opened_SS-HJ_addLatiLongti.csv')
df_org
# Out:
#          번호       인허가일자  영업상태구분코드                 소재지전체주소   Latitude  \
# 0      7502  2023-08-16         1  강원특별자치도 춘천시 석사동 654-19  37.859445
# 1      7519  2023-08-09         1   강원특별자치도 춘천시 석사동 885-3  37.852339
# 2      7523  2023-08-11         1  강원특별자치도 춘천시 효자동 590-48  37.869167
# 3      7524  2023-08-11         1   강원특별자치도 춘천시 효자동 652-3  37.875470
# 4      7526  2023-08-04         1  강원특별자치도 춘천시 효자동 305-46  37.864947
# ...     ...         ...       ...                     ...        ...
# 1167  12398  2023-09-20         1   강원특별자치도 춘천시 석사동 840-9  37.853174
# 1168  10155  2023-03-08         1   강원특별자치도 춘천시 석사동 818-1  37.856496
# 1169  10156  2023-03-08         1  강원특별자치도 춘천시 효자동 748-13  37.878113
# 1170  10158  2023-03-09         1  강원특별자치도 춘천시 효자동 628-14  37.873420
# 1171  10162  2022-10-17         1  강원특별자치도 춘천시 효자동 694-11  37.867858
#
#        Longitude               사업장명 업태구분명   시설총규모               최종수정시점  \
# 0     127.740166              백돈춘천점    기타   86.13  2023-08-16 14:35:53
# 1     127.745196              야미마라탕   중국식   96.00  2023-08-11 16:34:22
# 2     127.725577             곰소젓갈밥상    한식   87.84  2023-08-11 16:26:26
# 3     127.735500                호앤호    기타  112.00  2023-08-21 16:31:40
# 4     127.734955         넘버25호텔남춘천점    기타   53.04   2023-08-07 8:58:17
# ...          ...                ...   ...     ...                  ...
# 1167  127.746671               밥의민족    한식  105.00  2023-10-23 15:10:45
# 1168  127.742842          김밥나라봄내초교점    한식   59.69  2023-03-14 17:30:24
# 1169  127.739507  케이크베이크(cake bake)    기타   38.00  2023-03-31 10:34:40
# 1170  127.743982               공식술상    기타  138.33  2023-08-31 17:08:39
# 1171  127.728497                스시젠    일식   50.00   2022-10-28 9:44:55
#
#           시/도  구/군  동/면    상세주소
# 0     강원특별자치도  춘천시  석사동  654-19
# 1     강원특별자치도  춘천시  석사동   885-3
# 2     강원특별자치도  춘천시  효자동  590-48
# 3     강원특별자치도  춘천시  효자동   652-3
# 4     강원특별자치도  춘천시  효자동  305-46
# ...       ...  ...  ...     ...
# 1167  강원특별자치도  춘천시  석사동   840-9
# 1168  강원특별자치도  춘천시  석사동   818-1
# 1169  강원특별자치도  춘천시  효자동  748-13
# 1170  강원특별자치도  춘천시  효자동  628-14
# 1171  강원특별자치도  춘천시  효자동  694-11
#
# [1172 rows x 14 columns]

# %%
# '번호' column 이름을 'index'로 변경
df_org.rename(columns={'번호':'index_cafeteria'}, inplace=True)

# %%
# 저장
df_org.to_csv('../data/c4_general_cafeteria_chuncheon_CC_opened_SS-HJ_addLatiLongti.csv', index=False)

# %%
df_menu = pd.read_csv('../data/c4_general_cafeteria_chuncheon_CC_opened_SS-HJ_addLatiLongti_menu-price.csv')

# %%
# df_menu['index_cafeteria']의 인덱스를 플로트가 아닌 인트로 바꿔준다.
df_menu['index_cafeteria'] = df_menu['index_cafeteria'].astype(int)

# %%
# 저장
df_org.to_csv('../data/c4_general_cafeteria_chuncheon_CC_opened_SS-HJ_addLatiLongti_menu-price.csv', index=False)
